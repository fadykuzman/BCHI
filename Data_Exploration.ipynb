# %% [markdown]
# # Analysing the data from Big Cities Health Coalitions

# %% [markdown]
# ## Import libraries and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

ls = os.listdir()

# %%
ls
# Out:
# ['Untitled.ipynb', 'bchi.csv', '.ipynb_checkpoints']

# %%
all_data = pd.read_csv('bchi.csv')

# %%
all_data.head()
# Out:
#                   Indicator Category  \
# 0  Behavioral Health/Substance Abuse
# 1  Behavioral Health/Substance Abuse
# 2  Behavioral Health/Substance Abuse
# 3  Behavioral Health/Substance Abuse
# 4  Behavioral Health/Substance Abuse
#
#                                            Indicator  \
# 0  Opioid-Related Unintentional Drug Overdose Mor...
# 1  Opioid-Related Unintentional Drug Overdose Mor...
# 2  Opioid-Related Unintentional Drug Overdose Mor...
# 3  Opioid-Related Unintentional Drug Overdose Mor...
# 4  Opioid-Related Unintentional Drug Overdose Mor...
#
#                  Shortened Indicator Name Shortened Indicator Name (Graph)  \
# 0  Opioid-Related Overdose Mortality Rate                              NaN
# 1  Opioid-Related Overdose Mortality Rate                              NaN
# 2  Opioid-Related Overdose Mortality Rate
# 3  Opioid-Related Overdose Mortality Rate                              NaN
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25441 entries, 0 to 25440
# Data columns (total 17 columns):
# Indicator Category                  25441 non-null object
# Indicator                           25441 non-null object
# Shortened Indicator Name            25441 non-null object
# Shortened Indicator Name (Graph)    5561 non-null object
# Year                                25441 non-null int64
# Sex                                 25441 non-null object
# Race/Ethnicity                      25441 non-null object
# Value                               23277 non-null object
# Place                               25441 non-null object
# BCHC Requested Methodology          25441 non-null object
# Source                              20998 non-null object
# Methods                             5694 non-null object
# Notes                               8415 non-null object
# 90% Confidence Level - Low          2953 non-null object
# ...

# %%
columns = all_data.columns

# %%
description_dict = {}
for column in columns:
    if column in description_dict:
        continue
    else:
        description_dict[column] = all_data[column].describe()

# %%
description_dict
# Out:
# {'90% Confidence Level - High': count     2953
#  unique    1088
#  top        0.3
#  freq        28
#  Name: 90% Confidence Level - High, dtype: object,
#  '90% Confidence Level - Low': count     2953
#  unique    1007
#  top        0.1
#  freq        31
#  Name: 90% Confidence Level - Low, dtype: object,
#  '95% Confidence Level - High': count     4232
#  unique    2394
#  top       12.4
#  freq        14
#  Name: 95% Confidence Level - High, dtype: object,
#  '95% Confidence Level - Low': count     4232
#  unique    2213
#  top        1.6
#  freq        20
#  Name: 95% Confidence Level - Low, dtype: object,
#  'BCHC Requested Methodology': count                                                 25441
#  unique                                                  326
#  top       Incidence reported as a crude rate per 100,000...
#  freq                                                   2899
#  Name: BCHC Requested Methodology, dtype: object,
# ...

# %%
all_data[['Shortened Indicator Name', 'Shortened Indicator Name (Graph)']]
# Out:
#                      Shortened Indicator Name Shortened Indicator Name (Graph)
# 0      Opioid-Related Overdose Mortality Rate                              NaN
# 1      Opioid-Related Overdose Mortality Rate                              NaN
# 2      Opioid-Related Overdose Mortality Rate
# 3      Opioid-Related Overdose Mortality Rate                              NaN
# 4      Opioid-Related Overdose Mortality Rate                              NaN
# 5      Opioid-Related Overdose Mortality Rate                              NaN
# 6      Opioid-Related Overdose Mortality Rate                              NaN
# 7      Opioid-Related Overdose Mortality Rate                              NaN
# 8      Opioid-Related Overdose Mortality Rate                              NaN
# 9      Opioid-Related Overdose Mortality Rate                              NaN
# 10     Opioid-Related Overdose Mortality Rate
# 11     Opioid-Related Overdose Mortality Rate                              NaN
# ...

# %%
all_data = all_data.drop('Shortened Indicator Name (Graph)', axis=1)

# %%
all_data.columns
# Out:
# Index(['Indicator Category', 'Indicator', 'Shortened Indicator Name', 'Year',
#        'Sex', 'Race/Ethnicity', 'Value', 'Place', 'BCHC Requested Methodology',
#        'Source', 'Methods', 'Notes', '90% Confidence Level - Low',
#        '90% Confidence Level - High', '95% Confidence Level - Low',
#        '95% Confidence Level - High'],
#       dtype='object')

# %%
all_data['Indicator Category'].unique()
# Out:
# array(['Behavioral Health/Substance Abuse', 'Cancer', 'Chronic Disease',
#        'Demographics', 'Environmental Health', 'Food Safety', 'HIV/AIDS',
#        'Infectious Disease', 'Injury/Violence',
#        'Life Expectancy and Death Rate (Overall)',
#        'Maternal and Child Health', 'Sexually Transmitted Infections'], dtype=object)

# %%
all_data[]
